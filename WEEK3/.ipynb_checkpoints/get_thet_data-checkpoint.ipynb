# %%
import requests
import json
from bs4 import BeautifulSoup
import feedparser

#Nosso primeiro passo foi importar todas as bibliotecas necessárias para o nosso programa

# %% [markdown]
# O primeiro site que escolhemos para fazer o webscraping foi o Adorocinema, nosso objetivo é selecionar categorias de título, direçao, elenco, ratings, etc...

# %%
adorocinema1 = 'http://www.adorocinema.com/filmes/numero-cinemas/'
page = requests.get(adorocinema1)

# %% [markdown]
# Agora usamos a função page.status_code para verificar se o link esta respondendo e que será factível para o uso do web scraping:

# %%
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# O primeiro parametro escolhido para fazer o web scraping será o título dos filmes, assim  analisamos na pagina para encontrar a classe. A segunda categoria escolhida foi a data de estreia do filme, então novamente nós procuramos a classe das datas. A terceira categoria utilizada para fazer o webscraping foi o diretor do filme, para isso mais uma vez identificamos a classe e limpamos o ruido remanecente do texto na célula seguinte

# %%
title = soup.find_all('a',class_="meta-title-link")
date = soup.find_all('span',class_="date")
director = soup.find_all('a',class_="blue-link")

# %% [markdown]
# Depois nos limpamos as listas através da função split()

# %%
title_t = [title[i].get_text().split(">") for i in range(len(title))]
title_t = [word for i in title for word in i]
date_t = [date[i].get_text().split(">") for i in range(len(date))]
date_t = [word for i in date for word in i]
director_t = [director[i].get_text().split(">") for i in range(len(director))]
director_t = [word for i in director for word in i]

# %% [markdown]
# O proximo passo é criar um loop para fazer o mesmo procedimento nas próximas páginas:

# %%
title2 = []
date2 = []
director2 = []

for i in range(2,5):
    adorocinema2 = f'http://www.adorocinema.com/filmes/numero-cinemas/?page={i}'
    page2 = requests.get(adorocinema2)
    soup2 = BeautifulSoup(page2.content, 'html.parser')
    
    title2.append(soup2.find_all('a',class_="meta-title-link"))
    t2 = [word for i in title2 for word in i]
    t2_t = [t2[i].get_text().split(">") for i in range(len(t2))]
    t2_t = [word for i in t2_t for word in i]
    date2.append(soup2.find_all('span',class_="date"))
    d2 = [word for i in date2 for word in i]
    d2_t = [d2[i].get_text().split(">") for i in range(len(d2))]
    d2_t = [word for i in d2_t for word in i]
    director2.append(soup2.find_all('a',class_="blue-link"))
    dr2 = [word for i in director2 for word in i]
    dr2_t = [dr2[i].get_text().split(">") for i in range(len(dr2))]
    dr2_t = [word for i in dr2_t for word in i]

# %%
for i in range(len(t2_t)):
    title_t.append(t2_t[i])
    date_t.append(d2_t[i])
    director_t.append(dr2_t[i])

# %% [markdown]
# Devido à impossibilidades técnicas em relação à formatação das informações do site, não conseguimos extrair mais informações de colunas do site, por isso decidimos criar o dataframe e fazer webscraping em outro site:

# %%
import pandas as pd

adorocinema_df = {
        'Título': (title_t),
        'Data de lançamento': (date_t),
        'Direção': (director_t),
}
    
    
df_info = pd.DataFrame(adorocinema_df, columns = ['Título', 'Data de lançamento','Direção'])

# %%
df_info
# Out:
#                                                Título      Data de lançamento  \
# 0                                             Coringa    3 de outubro de 2019
# 1                                          Abominável  26 de setembro de 2019
# 2                             Angry Birds 2 - O Filme    3 de outubro de 2019
# 3                         Ad Astra - Rumo às Estrelas  26 de setembro de 2019
# 4                                Ela Disse, Ele Disse    3 de outubro de 2019
# 5                               Predadores Assassinos  26 de setembro de 2019
# 6                                    Rambo: Até o Fim  19 de setembro de 2019
# 7                          Hebe - A Estrela do Brasil  26 de setembro de 2019
# 8                                     It - Capítulo 2   5 de setembro de 2019
# 9                           Vai que Cola 2 - O Começo  12 de setembro de 2019
# 10                      Divaldo - O Mensageiro da Paz  12 de setembro de 2019
# 11                                            Bacurau    29 de agosto de 2019
# 12                                         O Rei Leão     18 de julho de 2019
# 13                                          Yesterday    29 de agosto de 2019
# 14                                  O Poderoso Chefão     24 de março de 1972
# 15                                  Ambiente Familiar  26 de setembro de 2019
# 16                                    Rainha de Copas  12 de setembro de 2019
# 17                                    De Peito Aberto    3 de outubro de 2019
# 18                        Era uma Vez em... Hollywood    15 de agosto de 2019
# 19                              A Turma do Pererê.doc    3 de outubro de 2019
# 20                               O Clube dos Canibais    3 de outubro de 2019
# 21  Paulo de Tarso e a História do Cristianismo Pr...    3 de outubro de 2019
# 22                                          Encontros    3 de outubro de 2019
# 23                                           Sócrates  26 de setembro de 2019
# 24                                            Domingo    3 de outubro de 2019
# 25                                        A Tabacaria   5 de setembro de 2019
# 26                                     O Homem Ideal?    3 de outubro de 2019
# 27                                  O Homem que Cuida    3 de outubro de 2019
# 28                                    Nada a Perder 2    15 de agosto de 2019
# 29                                Depois do Casamento  19 de setembro de 2019
# 30                                   O Maior Presente  19 de setembro de 2019
# 31               O Mal Não Espera a Noite - Midsommar  19 de setembro de 2019
# 32                                As Loucuras de Rose    3 de outubro de 2019
# 33                          Carta para Além dos Muros  26 de setembro de 2019
# 34                  O Fim da Viagem, o Começo de Tudo  12 de setembro de 2019
# 35                             Vai que Cola - O Filme    1 de outubro de 2015
# 36                                  Pássaros de Verão    22 de agosto de 2019
# 37                             O Menino que Fazia Rir  26 de setembro de 2019
# 38                                       Dor e Glória     13 de junho de 2019
# 39                                 Torre das Donzelas  19 de setembro de 2019
# 40                            Quem Você Pensa que Sou  12 de setembro de 2019
# 41                                      Filhas do Sol  26 de setembro de 2019
# 42                                         Legalidade  12 de setembro de 2019
# 43                                     Corgi: Top Dog   5 de setembro de 2019
# 44                                        Foro Íntimo  26 de setembro de 2019
# 45                             A Música da Minha Vida  19 de setembro de 2019
# 46                   Velozes & Furiosos: Hobbs & Shaw     1 de agosto de 2019
# 47                 Pets - A Vida Secreta dos Bichos 2     27 de junho de 2019
#
#                   Direção
# 0           Todd Phillips
# 1             Jill Culton
# 2        Thurop Van Orman
# 3              James Gray
# 4          Cláudia Castro
# 5           Alexandre Aja
# 6         Adrian Grunberg
# 7         Maurício Farias
# 8         Andy Muschietti
# 9         César Rodrigues
# 10           Clovis Mello
# 11  Kleber Mendonça Filho
# 12            Jon Favreau
# 13            Danny Boyle
# 14   Francis Ford Coppola
# 15          Torquato Joel
# 16          May el-Toukhy
# 17   Graziela Mantoanelli
# 18      Quentin Tarantino
# 19        Ricardo Favilla
# 20           Guto Parente
# 21          André Marouço
# 22        Cédric Klapisch
# 23           Alex Moratto
# 24        Fellipe Barbosa
# 25     Nikolaus Leytner\t
# 26        Carles Alberola
# 27      Alejandro Andújar
# 28     Alexandre Avancini
# 29        Bart Freundlich
# 30     Juan Manuel Cotelo
# 31              Ari Aster
# 32       Tom Harper (III)
# 33            André Canto
# 34       Kiyoshi Kurosawa
# 35        César Rodrigues
# 36            Ciro Guerra
# 37          Caroline Link
# 38        Pedro Almodóvar
# 39           Susanna Lira
# 40            Safy Nebbou
# 41             Eva Husson
# 42             Zeca Brito
# 43            Ben Stassen
# 44        Ricardo Mehedff
# 45        Gurinder Chadha
# 46           David Leitch
# 47           Chris Renaud

# %%
df_info.to_csv('df_adorocinema.csv')

# %% [markdown]
# Como nosso segundo objetivo iremos fazer webscraping no site de notícas, o site escolhido foi o UOL. Dessa vez optamos fazer a captação de dados através do RSS, que usa formatos de feed de internet padrão para publicar informações atualizadas com freqüência, o que combina bastante com o nosso caso de utilizar um blog de notícias.
#
# O documento RSS  inclui Texto resumido e metadados, como data de publicação, link de acesso ao conteúdo e nome do autor. O leitor de RSS verifica os feeds regularmente para obter novas informações e pode baixá-lo automaticamente, se essa função estiver ativada. O leitor também fornece uma interface de usuário, que o caso dos navegadores modernos.

# %%
uol = feedparser.parse('http://rss.home.uol.com.br/index.xml')

#para isso primeiro acessamos o link do blog de noticias UOL em RSS

# %% [markdown]
# Em seguida geramos o dataframe com todas as informações que o documento RSS nos forneceu e para acessar as informações, geramos uma visualização com a função .head().
#
# Muitas das informações fornecidas não foram usadas, o critério utilizado foi focado mais nas informações que seriam interessantes serem usadas e que estariam disponiveis visualmente no site ao ser acessado do que nas informaçoes que acreditamos que deveriam ser excliudas. Por isso, apos analisar o documento, decidios trabalahar com os dados do título, resumo da notícia, data da publicação e créditos da noticia.

# %%
df_uol = pd.DataFrame(uol.entries)
df_uol.head(2)
# Out:
#                                              content  credit  guidislink  \
# 0                                                NaN     NaN        True
# 1  [{'type': 'text/plain', 'language': None, 'bas...  Pexels        True
#
#                                                   id  \
# 0  https://www1.folha.uol.com.br/poder/2019/10/bo...
# 1  https://noticias.uol.com.br/cotidiano/ultimas-...
#
#                                                 link  \
# 0  https://www1.folha.uol.com.br/poder/2019/10/bo...
# 1  https://noticias.uol.com.br/cotidiano/ultimas-...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                        media_content  \
# 0                                                NaN
# 1  [{'url': 'http://conteudo.imguol.com.br/c/home...
#
#                                         media_credit  \
# 0                                                NaN
# 1  [{'role': 'author', 'scheme': 'urn:ebu', 'cont...
#
#                          published                      published_parsed  \
# 0  Fri, 04 Oct 2019 12:50:49 -0300  (2019, 10, 4, 15, 50, 49, 4, 277, 0)
# 1  Fri, 04 Oct 2019 11:50:22 -0300  (2019, 10, 4, 14, 50, 22, 4, 277, 0)
#
#                                              summary  \
# 0  Bolsonaro manterá no cargo ministro indiciado ...
# 1  IBGE: 2,7% das famílias concentram 20% de toda...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': None, 'base'...
# 1  {'type': 'text/html', 'language': None, 'base'...
#
#                                                title  \
# 0  Investigação desde o começo do ano | Bolsonaro...
# 1  Em 2017 e 2018 | IBGE: 2,7% das famílias conce...
#
#                                         title_detail
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...

# %%
df_uol['Tamanho do titulo'] = df_uol['title'].apply(len)
df_final = df_uol[['title','Tamanho do titulo']].sort_values('Tamanho do titulo', ascending=False)

# %%
df_final['Resumo'] = df_uol['summary']
df_final['Data da publicação'] = df_uol['published']
df_final ['Creditos da noticia'] = df_uol ['credit']

# %%
df_final
# Out:
#                                                 title  Tamanho do titulo  \
# 0   Investigação desde o começo do ano | Bolsonaro...                105
# 12  Em entrevista a site | Lula diz que ficou como...                 98
# 8   Mortes viram 'suicídios' | Projeto de Flávio B...                 98
# 3   Vereadora assassinada | Motorista de Marielle,...                 96
# 9   Nem herói nem coitado | Tetraplégico após assa...                 96
# 4   Indícios de desvios do MP | Supremo vai aciona...                 94
# 19  Em busca do passado | 'É doloroso não saber de...                 94
# 6   Disputa entre facções | Guerra do tráfico no R...                 93
# 21  Meteoro por Trás da Cena | Por que Handmaid's ...                 93
# 20  O futebol como escola de vida | Betão relata r...                 91
# 15  Hoje no Rock in Rio | Iron Maiden trará Eddie ...                 90
# 5   Dados do Enade | Só 3% dos cursos superiores p...                 87
# 10  Violência em SP | Professora estuprada em esco...                 86
# 2   Sancionado hoje | Novo marco das telecomunicaç...                 85
# 11  Catimba | Ministério da Economia: Liga do Cart...                 83
# 1   Em 2017 e 2018 | IBGE: 2,7% das famílias conce...                 82
# 14  Ouça o podcast | Baixo Clero discute a desidra...                 79
# 17  Palmeiras | Mano supera arrancada de Felipão q...                 77
# 18  Fique atento! | Completar nível de óleo no pos...                 75
# 13  Eleição no domingo | Conselho Tutelar: saiba c...                 74
# 16  Opinião | Feltrin: Nada acontece com Silvio, e...                 70
# 22  Reinaldo Azevedo | Em SP, procurador prova que...                 64
# 28  Renata Mendonça | Demorou, mas futebol feminin...                 64
# 33  Tati Bernardi | Eu dizia que tenho medo de tud...                 64
# 24  Paola Machado | Treino funcional ajuda quem te...                 63
# 7   Semana tensa | Desgaste entre Paulo Guedes e B...                 62
# 23  Josias de Souza | Propaganda sobre pacote de M...                 61
# 30  Ruy Castro | Bolsonaro referiu-se à árvore de ...                 59
# 32  H. Schwartsman | O que se temia está acontecen...                 59
# 27  Gustavo Fogaça | Quais as reais chances de Grê...                 57
# 31  Renato Terra | A lista de rejeições do ex-pres...                 57
# 29  Boghossian | Incentivo à matança policial ofen...                 56
# 26   Djamila Ribeiro | Os brancos também sabem dançar                 48
# 25          Dunker | Somos ainda analfabetos digitais                 41
#
#                                                Resumo  \
# 0   Bolsonaro manterá no cargo ministro indiciado ...
# 12  Lula diz que ficou comovido com ligação de Gil...
# 8   Projeto de Flávio Bolsonaro incentiva ações de...
# 3   Motorista de Marielle, Anderson era seguido do...
# 9   Tetraplégico após assalto, Rodrigo critica ide...
# 4   Supremo vai acionar PGR para tentar validar me...
# 19  'É doloroso não saber de onde vim': eles foram...
# 6   Guerra do tráfico no RJ deixa um morto e 6 fer...
# 21  Por que Handmaid's Tale é a distopia mais pare...
# 20  Betão relata racismo na Ucrânia: 'Vovó, o negr...
# 15  Iron Maiden trará Eddie capetão, lança-chamas ...
# 5   Só 3% dos cursos superiores privados têm nota ...
# 10  Professora estuprada em escola hesitou em faze...
# 2   Novo marco das telecomunicações muda foco de t...
# 11  Ministério da Economia: Liga do Cartola é tão ...
# 1   IBGE: 2,7% das famílias concentram 20% de toda...
# 14  Baixo Clero discute a desidratação da Lava Jat...
# 17  Mano supera arrancada de Felipão que levou a t...
# 18  Completar nível de óleo no posto pode não ser ...
# 13  Conselho Tutelar: saiba como eleger os represe...
# 16  Feltrin: Nada acontece com Silvio, ele só está...
# 22      Em SP, procurador prova que Moraes está certo
# 28     Demorou, mas futebol feminino chegou pra ficar
# 33   Eu dizia que tenho medo de tudo que não controlo
# 24    Treino funcional ajuda quem tem hérnia de disco
# 7     Desgaste entre Paulo Guedes e Bolsonaro aumenta
# 23        Propaganda sobre pacote de Moro chega tarde
# 30     Bolsonaro referiu-se à árvore de forma injusta
# 32         O que se temia está acontecendo na cultura
# 27           Quais as reais chances de Grêmio e Inter
# 31         A lista de rejeições do ex-presidente Lula
# 29        Incentivo à matança policial ofende vítimas
# 26                     Os brancos também sabem dançar
# 25                   Somos ainda analfabetos digitais
#
#                  Data da publicação           Creditos da noticia
# 0   Fri, 04 Oct 2019 12:50:49 -0300                           NaN
# 12  Fri, 04 Oct 2019 11:39:36 -0300                           NaN
# 8   Fri, 04 Oct 2019 12:03:04 -0300                           NaN
# 3   Fri, 04 Oct 2019 11:50:22 -0300                           NaN
# 9   Fri, 04 Oct 2019 11:39:36 -0300            Pablo Saborido/UOL
# 4   Fri, 04 Oct 2019 11:50:22 -0300                           NaN
# 19  Fri, 04 Oct 2019 08:48:43 -0300                      Arte/UOL
# 6   Fri, 04 Oct 2019 12:03:04 -0300  JOSE LUCENA/ESTADÃO CONTEÚDO
# 21  Fri, 04 Oct 2019 08:48:43 -0300                    Divulgação
# 20  Fri, 04 Oct 2019 08:48:43 -0300                Caio Cezar/UOL
# 15  Fri, 04 Oct 2019 12:46:55 -0300           Divulgação/Facebook
# 5   Fri, 04 Oct 2019 12:03:04 -0300       Silva Junior/Folhapress
# 10  Fri, 04 Oct 2019 11:39:36 -0300        Reprodução/Google Maps
# 2   Fri, 04 Oct 2019 11:50:22 -0300                  Getty Images
# 11  Fri, 04 Oct 2019 11:39:36 -0300                           NaN
# 1   Fri, 04 Oct 2019 11:50:22 -0300                        Pexels
# 14  Fri, 04 Oct 2019 12:46:55 -0300                      Arte/UOL
# 17  Fri, 04 Oct 2019 12:46:55 -0300            DIEGO VARA/REUTERS
# 18  Fri, 04 Oct 2019 12:46:55 -0300                    Divulgação
# 13  Fri, 04 Oct 2019 12:46:55 -0300                        iStock
# 16  Fri, 04 Oct 2019 12:46:55 -0300                Reprodução/SBT
# 22  Fri, 04 Oct 2019 09:00:30 -0300                           UOL
# 28  Fri, 04 Oct 2019 09:00:30 -0300                    Divulgação
# 33  Fri, 04 Oct 2019 09:00:30 -0300      Keiny Andrade/Folhapress
# 24  Fri, 04 Oct 2019 09:00:30 -0300                    Reprodução
# 7   Fri, 04 Oct 2019 12:03:04 -0300                           NaN
# 23  Fri, 04 Oct 2019 09:00:30 -0300                Lucas Lima/UOL
# 30  Fri, 04 Oct 2019 09:00:30 -0300     Ricardo Borges/Folhapress
# 32  Fri, 04 Oct 2019 09:00:30 -0300       Bruno Santos/Folhapress
# 27  Fri, 04 Oct 2019 09:00:30 -0300               Arquivo pessoal
# 31  Fri, 04 Oct 2019 09:00:30 -0300      Bruno Santos/ Folhapress
# 29  Fri, 04 Oct 2019 09:00:30 -0300      Pedro Ladeira/Folhapress
# 26  Fri, 04 Oct 2019 09:00:30 -0300                Lucas Lima/UOL
# 25  Fri, 04 Oct 2019 09:00:30 -0300                           UOL

# %%
df_final.to_csv('df_uol.csv')
