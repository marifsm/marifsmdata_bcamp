# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
foo = ['stone', 'paper', 'scissors']
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
max_n_games = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
games_win=(max_n_games+1)/2
games_win
# Out:
# 3.0

# %%
def game():
    
    win=0 
# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
    comp = random.choice(foo)
    
    
    # Define a function that asks your choice: 'stone', 'paper' or 'scissors'
    # you should only allow one of the 3 options. This is defensive programming.
    # If it is not stone, paper or scissors keep asking until it is.

    print("1: stone")
    print("2: paper")
    print("3: scissors")
    inp = int(input("Enter a number: "))
    if inp == 1:
        inp = "stone"
    elif inp == 2:
        inp = "paper"
    elif inp == 3:
        inp = "scissors"
    else:
        print("Invalid input!")

    # Define a function that resolves a combat.
    # Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

    # Create two variables that accumulate the wins of each participant

    #STONE
    if inp == 'stone':
        if comp == 'paper':
            print('machine wins')
            win=1
        elif comp == 'scissors':
            print('you won')
            win=2
        else:
            print('tie')
            win=0

    #PAPER
    if inp == 'paper':
        if comp == 'scissors':
            print('machine wins')
            win=1
        elif comp == 'stone':
            print('you won')
            win=2
        else:
            print('tie')
            win=0

    #SCISSORS
    if inp == 'scissors':
        if comp == 'stone':
            print('machine wins')
            win=1
        elif comp == 'scissors':
            print('you won')
            win=2
        else:
            print('tie')
            win=0

    return inp,comp,win

inp,comp,win = game()
# Out:
# 1: stone
# 2: paper
# 3: scissors
# Enter a number: 2
# machine wins

# %%
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
print('you choice:',inp)
print('machine choice:',comp)
# Out:
# you choice: paper
# machine choice: scissors

# %%
# Create a loop that iterates while no player reaches the minimum of wins
you_win=0
comp_win=0

while you_win < games_win and comp_win < games_win:
    inp,comp,win = game()
    if win==2:
        you_win+=1
    elif win==1:
        comp_win+=1
    else:
        you_win+=0
    print(" ")
    print('you choice:',inp)
    print('machine choice:',comp)
    print('score - you:',you_win,'machine:',comp_win)
    print(" ")
    
    
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

print(" ")
if you_win > comp_win:
    print('YOU ARE THE WINNER!')
else:
    print('the machine has won the game')
# Out:
# 1: stone
# 2: paper
# 3: scissors
# Enter a number: 1
# machine wins
#
# you choice: stone
# machine choice: paper
# score - you: 0 machine: 1
#
# 1: stone
# 2: paper
# 3: scissors
# Enter a number: 2
# tie
#
# you choice: paper
# machine choice: paper
# score - you: 0 machine: 1
#
# 1: stone
# 2: paper
# 3: scissors
# Enter a number: 2
# you won
#
# you choice: paper
# machine choice: stone
# score - you: 1 machine: 1
#
# 1: stone
# 2: paper
# 3: scissors
# Enter a number: 2
# machine wins
#
# you choice: paper
# machine choice: scissors
# score - you: 1 machine: 2
#
# 1: stone
# 2: paper
# 3: scissors
# Enter a number: 2
# you won
#
# you choice: paper
# machine choice: stone
# score - you: 2 machine: 2
#
# 1: stone
# 2: paper
# 3: scissors
# Enter a number: 2
# machine wins
#
# you choice: paper
# machine choice: scissors
# score - you: 2 machine: 3

# %% [markdown]
# ## Print by console the winner of the game based on who has more accumulated wins

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
numb_games = int(input("Enter an odd number for the number of matches: "))

if numb_games % 2 == 0:
    print("Invalid input!")
else:
    numb_games = numb_games

# Assign a list of 5 possible options.
lst = ['stone', 'paper', 'scissors', 'lizard','spock']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
max_n_games = 3


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
games_win=(max_n_games+1)/2

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def games1():

    win=0
    comp = random.choice(lst)

    # Define a function that asks your choice between 5
    # you should only allow one of the 5 options. This is defensive programming.
    # If it is not valid, keep asking until it is valid.

    print("1: stone")
    print("2: paper")
    print("3: scissors")
    print("4: lizard")
    print("5: spock")
    print("")

    inp = int(input("Enter a number: "))
    if inp == 1:
        inp = "stone"
    elif inp == 2:
        inp = "paper"
    elif inp == 3:
        inp = "scissors"
    elif inp == 4:
         inp = "lizard"
    elif inp == 5:
         inp = "spock"
    else:
        print("Invalid input!")

    # Define a function that resolves a combat.
    # Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
    # Now there are more options

    #STONE
        if inp == 'stone':
            if comp == 'paper' or comp == 'spock':
                print('machine wins')
                win=1
            elif comp == 'scissors' or comp == 'lizard':
                print('you won')
                win=2
            else:
                print('tie')
                win=0

      #PAPER
        if inp == 'paper':
            if comp == 'scissors' or comp == 'lizard':
                print('machine wins')
                win=1
            elif comp == 'stone' or comp == 'spock':
                print('you won')
                win=2
            else:
                print('tie')
                win=0

        #SCISSORS
        if inp == 'scissors':
            if comp == 'stone' or comp == 'spock':
                print('machine wins')
                win=1
            elif comp == 'scissors' or comp == 'lizard':
                print('you won')
                win=2
            else:
                print('tie')
                win=0

        #LIZARD
        if inp == 'lizard':
            if comp == 'stone' or comp == 'scissors':
                print('machine wins')
                win=1
            elif comp == 'paper' or comp == 'spock':
                print('you won')
                win=2
            else:
                print('tie')
                win=0

        #SPOCK
        if inp == 'spock':
            if comp == 'lizard' or comp == 'paper':
                print('machine wins')
                win=1
            elif comp == 'scissors' or comp == 'stone':
                print('you won')
                win=2
            else:
                print('tie')
                win=0

    return inp,comp,win

inp,comp,win = games1()
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
    
# Create two variables that accumulate the wins of each participant
you_win=0
comp_win=0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while you_win < games_win and comp_win < games_win:
    inp,comp,win = games1()
    if win==2:
        you_win+=1
    elif win==1:
        comp_win+=1
    else:
        you_win+=0
    print(" ")
    print('you choice:',inp)
    print('machine choice:',comp)
    print('score - you:',you_win,'machine:',comp_win)
    print(" ")
    
    
# Print by console the winner of the game based on who has more accumulated wins
