# %%
import pandas as pd

# %%
data_attacks = pd.read_csv('attacks.csv', encoding='latin-1')

# %%
data_attacks
# Out:
#         Case Number                  Date    Year          Type       Country  \
# 0        2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1        2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2        2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3        2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4        2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5      2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6      2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7        2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8      2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9      2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10       2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %%
data_attacks.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
#No total temos 25723 ataques na tabela. As duas ultimas colunas, que são nomeadas como Unamed: 22 e Unamed: 23 
#possuem mais de 99% dos seus valores nulos, por isso decidimos que faz sentido para a limpeza dos dados apagar 
#essas duas colunas


data_attacks.drop('Unnamed: 22', axis=1, inplace = True)
data_attacks.drop('Unnamed: 23', axis=1, inplace = True)

# %%
data_attacks.dropna(axis=0, how='all', subset=['href'], inplace = True)

## Após ter aberto o arquivo csv, verificamos que a partir de determinado ponto, as linhas nao continham 
#informacoes uteis para o data frame, por estarem faltando ou sendo nulas. Portanto, decicimos excluir estas 
#linhas.

# %%
data_attacks.rename(columns={'Sex	':'Sex'}, inplace = True)
data_attacks.rename(columns={'Species	':'Species'}, inplace = True)

# %%
data_attacks['Name'] = data_attacks['Name'].str.replace('female','Unknown')
data_attacks['Name'] = data_attacks['Name'].str.replace('male','Unknown')

# Em alguns casos em vez de colocar o nome da pessoa foi posto o gênero, por isso decidimos alinhar o dado de forma
# que a informação esteja coerente com a coluna, assim todas as vezes em que o nome esteja como male ou female, o nome será
# modificado para Unknown.

# %%
data_attacks = data_attacks.fillna('Unknown')
##Optamos pela opção de preencher os missing values 
## por outro valor das colunas 
##no caso o pela string Unknown. Pois, caso
##os valores dessa coluna fossem apagados 
##nós também perderiamos as informaçoes das 
##outras colunas, o que não seria 
##algo indesejável, pois muitas informações 
##seriam perdidas

# %%
dif_list=[]
dif_list2=[]
dif_list3=[]
dif_list4=[]

for i in range(len(data_attacks)):
    if data_attacks['href formula'][i]!=data_attacks['href'][i]:
        dif_list.append(i)
    if data_attacks['Case Number.1'][i]!=data_attacks['Case Number.2'][i]:
        dif_list2.append(i)
    if data_attacks['Case Number'][i]!=data_attacks['Case Number.1'][i]:
        dif_list3.append(i)
    if data_attacks['Case Number'][i]!=data_attacks['Case Number.2'][i]:
        dif_list4.append(i)
        
print(len(dif_list))
print(len(dif_list2))
print(len(dif_list3))
print(len(dif_list4))

data_attacks = data_attacks.drop('Case Number.1', axis=1)
data_attacks = data_attacks.drop('Case Number.2', axis=1)
data_attacks = data_attacks.drop('href formula', axis=1)


# Aparentemente, as colunas continham valores iguais, após análise por meio de um for loop e verificação manual, 
# foi possível identificar que, de fato, as diferenças eram muito poucas e decidimos manter apenas uma coluna com
# a informação.
# Out:
# 60
# 20
# 24
# 4

# %%
#import re

#i = 0

#for words in data_attacks['Time']:
 #   try:
  #      data_attacks['Time'][i] = re.sub('6|7|8|9|10|11+h(*\S)','Morning',words)
  #      data_attacks['Time'][i] = re.sub('(12|13|14|15|16|17|18)+h(*\S)','Afternoon',words)
  #      data_attacks['Time'][i] = re.sub('*19|20|21|22|23|24|1|2|3|4|5+h(*\S)','Night',words)
#        i += 1  
#    except:
#        continue
00
# Out:
# 0

# %%
morning = ['5', '6', '7', '8', '9', '10', '11']
afternoon = ['12', '13', '14', '15', '16', '17', '18']
night = ['19', '20', '21', '22', '23', '24', '0', '1', '2', '3', '4']

for i in range(len(data_attacks)):
    for time in morning:
        if  time in data_attacks['Time'][i]:
            data_attacks['Time'][i] = 'Morning'
            
    for time in afternoon:
        if  time in data_attacks['Time'][i]:
            data_attacks['Time'][i] = 'Afternoon'
            
    for time in night:
        if  time in data_attacks['Time'][i]:
            data_attacks['Time'][i] = 'Night'
            
# Para organizar a coluna dos horarios optamos em tentar organizar os ataques pelos tres turnos existentes: 
# manha, tarde e noite. Por isso todas as linhas que continham informação numérica alteramos para a forma de 
# “morning”, “afternoon”, or “night”
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
data_attacks['Time'] = data_attacks['Time'].replace(['Late afternoon','Midday','Early afternoon','Evening','P.M.','Dusk','After%'],'Afternoon')


data_attacks['Time'] = data_attacks['Time'].replace(['1Morning','0Morning','Early morning','A.M.'],'Morning')

# %%
data_attacks['Time'].value_counts()
# Out:
# Unknown                                                                  3354
# Morning                                                                  1942
# Afternoon                                                                 813
# Night                                                                     132
# --                                                                          5
# Midnight                                                                    4
# Sunset                                                                      4
# Late afternon                                                               2
# Just before noon                                                            2
# Dark                                                                        2
#                                                                             2
# After noon                                                                  2
# ...

# %%
data_attacks = data_attacks.drop('pdf', axis=1)

## Decidimos deletar a coluna com os dados do pdf, pois essa coluna consiste em informações que 
## se repetem em outras colunas como o número do caso, nome, localização, etc

# %%
data_attacks['Sex'].replace(['M ', 'lli', 'N', '.'], 'Unkwown')
data_attacks['Fatal (Y/N)'].replace(['M', 'UNKNOWN', '2017'], 'Unkwown')

#Funções feitas para substituir os valores considerados errados nas listas e substituidos por desconhecido
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-44e1f86e66e1> in <module>
# ...

# %%
data_attacks = data_attacks.drop('Year', axis=1)

## as informações contidas na coluna Date possuem os valores dos anos, tornando-se assim redundante trabalhar
## também com a coluna 'year'. Decidimos deletar a coluna com os dados do yeat, pois essa coluna consiste em informações 
## menos organizadas e completas quando comparadas com a coluna 'date'.

# %%
for i in range(len(data_attacks)):
    if i < 10:
        data_attacks['Case Number'][i] = f'CN_0000{i}'
    if i < 100:
        data_attacks['Case Number'][i] = f'CN_000{i}'
    if i < 1000:
        data_attacks['Case Number'][i] = f'CN_00{i}'
    else:
        data_attacks['Case Number'][i] = f'CN_0{i}'
    
# Para tornar um index confiável padronizamos a coluna do numero do caso da segunte forma 
# CN_OO(número da linha)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# ...

# %%
data_attacks

# %%
def lixeira(x):
    y = re.findall(r'([A-Z][a-z]*\s[A-Z][a-z]*)',x)
    if y==[]:
        return "Unknown"
    else:
        return y[0]

# %%
data_attacks["Name"] =  data_attacks["Name"].apply(lixeira)
data_attacks['Name'].value_counts()
# Out:
# Unknown                 2017
# Torres Strait              9
# Indian Unknown             5
# John Mc                    5
# James C                    4
# Thomas Mc                  4
# Zulu Unknown               4
# Danie Schoeman             4
# William Mc                 3
# John Williams              3
# Russian Unknown            3
# John P                     3
# John William               3
# A Japanese                 3
# James F                    3
# Andre Hartman              3
# Paul Mc                    2
# James Edward               2
# Wayne Monk                 2
# Harry Griffet              2
# Anton Bosman               2
# Seth Mead                  2
# Robert Martin              2
# Gerjo Van                  2
# American Unknown           2
# Hideo Ishida               2
# Theirry Mercredi           2
# Nguyen Thi                 2
# Gordon Harmer              2
# Japanese Unknown           2
#                         ...
# Gyula Plaganyi             1
# ...

# %%
import re

# %%
data_attacks.to_csv('data_attacks.csv')
